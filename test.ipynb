# %%
from gf_sandbox_client.sbc import Sbc

sbc = Sbc()
sbc.experiment.set('pi3b')
sbc.asset.set('shot_log')
sbc.columns.describe()
# Out:
#    asset_name                name           long_name  \
# 0    shot_log      argon_fraction      Argon fraction
# 1    shot_log        co2_fraction        CO2 fraction
# 2    shot_log     control_version     Control version
# 3    shot_log  deuterium_fraction  Deuterium fraction
# 4    shot_log           formation   Formation voltage
# 5    shot_log                 gap         Gap voltage
# 6    shot_log     helium_fraction     Helium fraction
# 7    shot_log   hydrogen_fraction   Hydrogen fraction
# 8    shot_log              ig1_on      Ion gauge 1 on
# 9    shot_log              ig2_on      Ion gauge 2 on
# 10   shot_log     ion_gauge_level     Ion gauge level
# 11   shot_log   manifold_pressure   Manifold pressure
# 12   shot_log               notes          Shot notes
# 13   shot_log             peaking     Peaking voltage
# 14   shot_log             preform     Preform voltage
# 15   shot_log          puff_width          Puff width
# 16   shot_log             sustain     Sustain voltage
# 17   shot_log           timestamp  Shot time and date
#
#                                           description  unit  order  \
# 0          Fraction of injected gas mix that is argon  None     40
# 1            Fraction of injected gas mix that is CO2  None     41
# 2           Version of the operating control software           47
# 3      Fraction of injected gas mix that is deuterium  None     38
# 4             Voltage of the formation capacitor bank     V     31
# 5                   Voltage of the gap capacitor bank     V     32
# 6         Fraction of injected gas mix that is helium  None     39
# 7       Fraction of injected gas mix that is hydrogen  None     37
# 8   Whether the ion gague in the pot or pumping ch...           44
# 9   Whether the ion gague in the pot or pumping ch...           45
# 10  Vacuum pressure in the vessel as the experimen...    Pa     43
# 11  Pressure of the gas that is injected into the ...    Pa     36
# 12          Operator comments when the shot was taken           48
# 13              Voltage of the peaking capacitor bank     V     33
# 14              Voltage of the preform capacitor bank     V     34
# 15                      Duration of the main gas puff     s     42
# 16              Voltage of the sustain capacitor bank     V     35
# 17                          Time and date of the shot           46
#
#     dependence      type  bits  nullable  low_cardinality default codec
# 0            4     Float  32.0     False            False    None  None
# 1            4     Float  32.0     False            False    None  None
# 2            4      Uint  16.0      True            False    None  None
# 3            4     Float  32.0     False            False    None  None
# 4            4     Float  32.0      True            False    None   FPC
# 5            4     Float  32.0      True            False    None   FPC
# 6            4     Float  32.0     False            False    None  None
# 7            4     Float  32.0     False            False    None  None
# 8            4      Uint   1.0      True            False    None  None
# 9            4      Uint   1.0      True            False    None  None
# 10           4     Float  32.0      True            False    None   FPC
# 11           4     Float  32.0      True            False    None   FPC
# 12           4    String   NaN      True            False    None  None
# 13           4     Float  32.0      True            False    None   FPC
# 14           4     Float  32.0      True            False    None   FPC
# 15           4     Float  32.0      True            False    None   FPC
# 16           4     Float  32.0      True            False    None   FPC
# 17           4  DateTime  32.0      True            False    None  None
